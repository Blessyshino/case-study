# %% [markdown]
# # Break out room 12

# %% [markdown]
# # Group members
# 1 Aliya Shagan
# 2.Blessy John
# 3.Akhil
# 4.Naseera
# 5.Silpa

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv(r'E:\blessy\ict\hotel_tips.csv')#reading dataset into python environment

# %%
data.head()#display head
# Out:
#    Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0      110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1      111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2      112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3      113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4      114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data['day'].value_counts()#finding customer count per day
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# # plotting bar graph day vs total bill

# %%
plt.bar(data['day'],data['total_bill'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # day vs size

# %%
plt.bar(data['day'],data['size'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['sex'],data['total_bill'])
plt.title('Sex Vs Total bill')
plt.xlabel('Sex')
plt.ylabel('Total bill')
plt.show()

# %%
plt.boxplot(data['tip']) 
plt.show()

# %%
plt.title('Time Basis')
sns.countplot(x=data.time)
plt.show()

# %%
sns.pairplot(data, hue='total_bill')

# %%
sns.countplot(x=data.smoker)
plt.show()

# %%
plt.pie(data['smoker'].value_counts())
y=data['smoker'].value_counts()
mylabels=["non_smoker","smoker"]
plt.pie(y,labels=mylabels)
plt.legend
plt.show()

# %%
plt.scatter(data['day'],data['size'])
plt.show()
